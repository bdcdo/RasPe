# %%
import legiscraper
scraper = legiscraper.scraper("DOU", id="632885940", displayDate="1748574000000")
# Out:
# 2025-06-02 11:20:34,437 - DOU - DEBUG - Download path set to /tmp/tmpmbaypos2

# %%
dados = scraper.scrape(pesquisa='doença rara', paginas=range(0, 2), debug=True)
print(dados)
# Out:
# 2025-06-02 11:24:15,535 - DOU - INFO - Starting scrape with parameters {'pesquisa': 'doença rara', 'paginas': range(0, 2), 'debug': True}
# 2025-06-02 11:24:15,536 - DOU - DEBUG - Setting query
# 2025-06-02 11:24:15,536 - DOU - DEBUG - {'q': 'doença rara', 's': 'todos', 'exactDate': 'all', 'sortType': '0', 'delta': '20', 'currentPage': '1', 'newPage': 1, 'score': '0', 'id': '632885940', 'displayDate': '1748574000000'}
# 2025-06-02 11:24:15,537 - DOU - DEBUG - Setting n_pags
# 2025-06-02 11:24:15,537 - DOU - DEBUG - Sending r0 (attempt 1/3)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Desktop/dev/legiscraper/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# ...
